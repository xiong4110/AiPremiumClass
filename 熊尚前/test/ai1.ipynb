# %% [markdown]
# 1. 获取数据
# 2. 创建模型，假设函数形式
# 3. 给参数赋初始值
# 4. 计算误差
# 5. 计算梯度
# 6. 更新参数
# 7. 循环迭代

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def get_data():
    x = np.linspace(-1,1,100)
    y = 10 * x**2 + 10*x + 5
    return x, y

a,b = get_data()
plt.plot(a,b)

# %%
# 创建模型，假设函数形式
w = [0,1,2,3]
def f(x):
    return w[0] * x**2 + w[1]*x + w[2] + w[3]

# %%
# 计算误差
def loss(y, y_hat):
    return np.sum((y - y_hat) ** 2) / len(y)

# %%
# 计算梯度
def gradient():
    grad = np.zeros(5)
